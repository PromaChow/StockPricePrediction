# %%
import os
import shutil
import subprocess
import tempfile
from google.cloud import storage

# %%
# Variables
LOCAL_REPO = "/home/manormanore/Documents/Git_Hub/StockPricePrediction/"
BUCKET_NAME = "stock_price_prediction_dataset"
BUCKET_PATH = "Codefiles"
PROJECT_ID = "striped-graph-440017-d7"

# Initialize GCS client using Application Default Credentials (ADC)
client = storage.Client(project=PROJECT_ID)
bucket = client.get_bucket(BUCKET_NAME)

# %%
# Create a temporary directory
with tempfile.TemporaryDirectory() as temp_dir:
    # Get list of files tracked by Git, excluding .gitignore patterns
    result = subprocess.run(
        ["git", "ls-files", "--cached", "--others", "--exclude-standard"],
        cwd=LOCAL_REPO,
        capture_output=True,
        text=True,
    )
    files = result.stdout.splitlines()
    
    # Filter for .py, .h5, and .ipynb files and copy them to the temp directory
    for file in files:
        if file.endswith(".py") or file.endswith(".h5") or file.endswith(".ipynb"):
            src_path = os.path.join(LOCAL_REPO, file)
            dest_path = os.path.join(temp_dir, file)
            os.makedirs(os.path.dirname(dest_path), exist_ok=True)
            shutil.copy2(src_path, dest_path)

    # Upload the temp directory contents to GCP Bucket
    for root, _, files in os.walk(temp_dir):
        for file in files:
            local_path = os.path.join(root, file)
            relative_path = os.path.relpath(local_path, temp_dir)
            blob_path = os.path.join(BUCKET_PATH, relative_path)
            blob = bucket.blob(blob_path)
            blob.upload_from_filename(local_path)
            print(f"Uploaded {relative_path} to gs://{BUCKET_NAME}/{blob_path}")

print("Selected .py, .h5, and .ipynb files uploaded to GCP bucket, excluding .gitignore entries.")
# Out:
# Uploaded GCP/filesbucket.ipynb to gs://stock_price_prediction_dataset/Codefiles/GCP/filesbucket.ipynb
# Uploaded GCP/synclocal.ipynb to gs://stock_price_prediction_dataset/Codefiles/GCP/synclocal.ipynb
# Uploaded GCP/GCPresorce.py to gs://stock_price_prediction_dataset/Codefiles/GCP/GCPresorce.py
# Uploaded src/linear_regression.ipynb to gs://stock_price_prediction_dataset/Codefiles/src/linear_regression.ipynb
# Uploaded src/XGBoost.ipynb to gs://stock_price_prediction_dataset/Codefiles/src/XGBoost.ipynb
# Uploaded src/data_preprocessing.ipynb to gs://stock_price_prediction_dataset/Codefiles/src/data_preprocessing.ipynb
# Uploaded src/SVM.ipynb to gs://stock_price_prediction_dataset/Codefiles/src/SVM.ipynb
# Uploaded src/Feature Engineering.ipynb to gs://stock_price_prediction_dataset/Codefiles/src/Feature Engineering.ipynb
# Uploaded src/PROJECT_DATA_CLEANING.ipynb to gs://stock_price_prediction_dataset/Codefiles/src/PROJECT_DATA_CLEANING.ipynb
# Uploaded src/FeatureEng_and_ModelBiasDetn.ipynb to gs://stock_price_prediction_dataset/Codefiles/src/FeatureEng_and_ModelBiasDetn.ipynb
# Uploaded src/KNN.ipynb to gs://stock_price_prediction_dataset/Codefiles/src/KNN.ipynb
# Uploaded src/RF_Model.ipynb to gs://stock_price_prediction_dataset/Codefiles/src/RF_Model.ipynb
# Uploaded src/ML Models.ipynb to gs://stock_price_prediction_dataset/Codefiles/src/ML Models.ipynb
# Uploaded src/DataSchema_Stats.ipynb to gs://stock_price_prediction_dataset/Codefiles/src/DataSchema_Stats.ipynb
# Uploaded src/LSTM.ipynb to gs://stock_price_prediction_dataset/Codefiles/src/LSTM.ipynb
# Uploaded tests/test_download_data.py to gs://stock_price_prediction_dataset/Codefiles/tests/test_download_data.py
# Uploaded tests/test_correlation.py to gs://stock_price_prediction_dataset/Codefiles/tests/test_correlation.py
# Uploaded tests/test_remove_weekend_data.py to gs://stock_price_prediction_dataset/Codefiles/tests/test_remove_weekend_data.py
# Uploaded tests/test_keep_latest_data.py to gs://stock_price_prediction_dataset/Codefiles/tests/test_keep_latest_data.py
# Uploaded tests/test_technical_indicators.py to gs://stock_price_prediction_dataset/Codefiles/tests/test_technical_indicators.py
# Uploaded tests/test_plot_yfinance_time_series.py to gs://stock_price_prediction_dataset/Codefiles/tests/test_plot_yfinance_time_series.py
# Uploaded tests/test_convert_column_dtype.py to gs://stock_price_prediction_dataset/Codefiles/tests/test_convert_column_dtype.py
# Uploaded tests/test_feature_interaction.py to gs://stock_price_prediction_dataset/Codefiles/tests/test_feature_interaction.py
# Uploaded tests/test_scaler.py to gs://stock_price_prediction_dataset/Codefiles/tests/test_scaler.py
# Uploaded tests/test_lagged_features.py to gs://stock_price_prediction_dataset/Codefiles/tests/test_lagged_features.py
# Uploaded tests/test_handle_missing.py to gs://stock_price_prediction_dataset/Codefiles/tests/test_handle_missing.py
# Uploaded tests/test_pca.py to gs://stock_price_prediction_dataset/Codefiles/tests/test_pca.py
# Uploaded pipeline/airflow/dags/airflow.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/dags/airflow.py
# Uploaded pipeline/airflow/dags/src/handle_missing.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/dags/src/handle_missing.py
# Uploaded pipeline/airflow/dags/src/download_data.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/dags/src/download_data.py
# Uploaded pipeline/airflow/dags/src/wandb_log.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/dags/src/wandb_log.py
# Uploaded pipeline/airflow/dags/src/convert_column_dtype.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/dags/src/convert_column_dtype.py
# Uploaded pipeline/airflow/dags/src/lagged_features.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/dags/src/lagged_features.py
# Uploaded pipeline/airflow/dags/src/keep_latest_data.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/dags/src/keep_latest_data.py
# Uploaded pipeline/airflow/dags/src/feature_interactions.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/dags/src/feature_interactions.py
# Uploaded pipeline/airflow/dags/src/scaler.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/dags/src/scaler.py
# Uploaded pipeline/airflow/dags/src/technical_indicators.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/dags/src/technical_indicators.py
# Uploaded pipeline/airflow/dags/src/remove_weekend_data.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/dags/src/remove_weekend_data.py
# Uploaded pipeline/airflow/dags/src/pca.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/dags/src/pca.py
# Uploaded pipeline/airflow/dags/src/correlation.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/dags/src/correlation.py
# Uploaded pipeline/airflow/dags/src/upload_blob.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/dags/src/upload_blob.py
# Uploaded pipeline/airflow/dags/src/plot_yfinance_time_series.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/dags/src/plot_yfinance_time_series.py
# Uploaded pipeline/airflow/dags/src/models/model_sensitivity_analysis.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/dags/src/models/model_sensitivity_analysis.py
# Uploaded pipeline/airflow/dags/src/models/model_utils.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/dags/src/models/model_utils.py
# Uploaded pipeline/airflow/dags/src/models/model_bias_detection.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/dags/src/models/model_bias_detection.py
# Uploaded pipeline/airflow/dags/src/models/XGBoost.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/dags/src/models/XGBoost.py
# Uploaded pipeline/airflow/dags/src/models/LSTM.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/dags/src/models/LSTM.py
# Uploaded pipeline/airflow/dags/src/models/linear_regression.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/dags/src/models/linear_regression.py
# Uploaded pipeline/airflow/tests/test_download_data.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/tests/test_download_data.py
# Uploaded pipeline/airflow/tests/test_correlation.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/tests/test_correlation.py
# Uploaded pipeline/airflow/tests/test_remove_weekend_data.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/tests/test_remove_weekend_data.py
# Uploaded pipeline/airflow/tests/test_keep_latest_data.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/tests/test_keep_latest_data.py
# Uploaded pipeline/airflow/tests/test_technical_indicators.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/tests/test_technical_indicators.py
# Uploaded pipeline/airflow/tests/test_plot_yfinance_time_series.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/tests/test_plot_yfinance_time_series.py
# Uploaded pipeline/airflow/tests/test_convert_column_dtype.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/tests/test_convert_column_dtype.py
# Uploaded pipeline/airflow/tests/test_feature_interaction.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/tests/test_feature_interaction.py
# Uploaded pipeline/airflow/tests/test_scaler.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/tests/test_scaler.py
# Uploaded pipeline/airflow/tests/test_lagged_features.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/tests/test_lagged_features.py
# Uploaded pipeline/airflow/tests/test_handle_missing.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/tests/test_handle_missing.py
# Uploaded pipeline/airflow/tests/test_pca.py to gs://stock_price_prediction_dataset/Codefiles/pipeline/airflow/tests/test_pca.py
# Uploaded models/linear_regression.ipynb to gs://stock_price_prediction_dataset/Codefiles/models/linear_regression.ipynb
# Uploaded models/XGBoost.ipynb to gs://stock_price_prediction_dataset/Codefiles/models/XGBoost.ipynb
# Uploaded models/SVM.ipynb to gs://stock_price_prediction_dataset/Codefiles/models/SVM.ipynb
# Uploaded models/FeatureEng_and_ModelBiasDetn.ipynb to gs://stock_price_prediction_dataset/Codefiles/models/FeatureEng_and_ModelBiasDetn.ipynb
# Uploaded models/KNN.ipynb to gs://stock_price_prediction_dataset/Codefiles/models/KNN.ipynb
# Uploaded models/RF_Model.ipynb to gs://stock_price_prediction_dataset/Codefiles/models/RF_Model.ipynb
# Uploaded models/ML Models.ipynb to gs://stock_price_prediction_dataset/Codefiles/models/ML Models.ipynb
# Uploaded models/LSTM.ipynb to gs://stock_price_prediction_dataset/Codefiles/models/LSTM.ipynb
# Selected .py, .h5, and .ipynb files uploaded to GCP bucket, excluding .gitignore entries.

# %%
BUCKET_PATH = "Codefiles"
PROJECT_ID = "striped-graph-440017-d7"

# Initialize GCS client using Application Default Credentials (ADC)
client = storage.Client(project=PROJECT_ID)
bucket = client.get_bucket(BUCKET_NAME)

# %%
# Create a temporary directory
with tempfile.TemporaryDirectory() as temp_dir:
    # Get list of files tracked by Git, excluding .gitignore patterns
    result = subprocess.run(
        ["git", "ls-files", "--cached", "--others", "--exclude-standard"],
        cwd=LOCAL_REPO,
        capture_output=True,
        text=True,
    )
    files = result.stdout.splitlines()
    
    # Filter for .csv and .png files and copy them to the temp directory
    for file in files:
        if file.endswith(".csv") or file.endswith(".png"):
            src_path = os.path.join(LOCAL_REPO, file)
            dest_path = os.path.join(temp_dir, file)
            os.makedirs(os.path.dirname(dest_path), exist_ok=True)
            shutil.copy2(src_path, dest_path)

    # Upload the temp directory contents to GCP Bucket
    for root, _, files in os.walk(temp_dir):
        for file in files:
            local_path = os.path.join(root, file)
            relative_path = os.path.relpath(local_path, temp_dir)
            blob_path = os.path.join(BUCKET_PATH, relative_path)
            blob = bucket.blob(blob_path)
            blob.upload_from_filename(local_path)
            print(f"Uploaded {relative_path} to gs://{BUCKET_NAME}/{blob_path}")

print("Selected CSV and PNG files uploaded to GCP bucket, excluding .gitignore entries.")
# Out:
# Uploaded data/final_dataset.csv to gs://stock_price_prediction_dataset/Data/data/final_dataset.csv
# Uploaded data/ADS_Index.csv to gs://stock_price_prediction_dataset/Data/data/ADS_Index.csv
# Uploaded data/merged_original_dataset.csv to gs://stock_price_prediction_dataset/Data/data/merged_original_dataset.csv
# Uploaded data/fama_french.csv to gs://stock_price_prediction_dataset/Data/data/fama_french.csv
# Uploaded data/formatted_datasets/ads_index.csv to gs://stock_price_prediction_dataset/Data/data/formatted_datasets/ads_index.csv
# Uploaded data/formatted_datasets/sp500.csv to gs://stock_price_prediction_dataset/Data/data/formatted_datasets/sp500.csv
# Uploaded data/formatted_datasets/historical_data.csv to gs://stock_price_prediction_dataset/Data/data/formatted_datasets/historical_data.csv
# Uploaded data/formatted_datasets/fama_french.csv to gs://stock_price_prediction_dataset/Data/data/formatted_datasets/fama_french.csv
# Uploaded data/formatted_datasets/fred_variables.csv to gs://stock_price_prediction_dataset/Data/data/formatted_datasets/fred_variables.csv
# Uploaded data/FRED_Variables/VIXCLS.csv to gs://stock_price_prediction_dataset/Data/data/FRED_Variables/VIXCLS.csv
# Uploaded data/FRED_Variables/DBAA.csv to gs://stock_price_prediction_dataset/Data/data/FRED_Variables/DBAA.csv
# Uploaded data/FRED_Variables/DCPN3M.csv to gs://stock_price_prediction_dataset/Data/data/FRED_Variables/DCPN3M.csv
# Uploaded data/FRED_Variables/CBBTCUSD.csv to gs://stock_price_prediction_dataset/Data/data/FRED_Variables/CBBTCUSD.csv
# Uploaded data/FRED_Variables/BAMLH0A0HYM2.csv to gs://stock_price_prediction_dataset/Data/data/FRED_Variables/BAMLH0A0HYM2.csv
# Uploaded data/FRED_Variables/BAMLH0A0HYM2EY.csv to gs://stock_price_prediction_dataset/Data/data/FRED_Variables/BAMLH0A0HYM2EY.csv
# Uploaded data/FRED_Variables/T10Y3M.csv to gs://stock_price_prediction_dataset/Data/data/FRED_Variables/T10Y3M.csv
# Uploaded data/FRED_Variables/DGS10.csv to gs://stock_price_prediction_dataset/Data/data/FRED_Variables/DGS10.csv
# Uploaded data/FRED_Variables/T10YIE.csv to gs://stock_price_prediction_dataset/Data/data/FRED_Variables/T10YIE.csv
# Uploaded data/FRED_Variables/T5YIE.csv to gs://stock_price_prediction_dataset/Data/data/FRED_Variables/T5YIE.csv
# Uploaded data/FRED_Variables/USRECDP.csv to gs://stock_price_prediction_dataset/Data/data/FRED_Variables/USRECDP.csv
# Uploaded data/FRED_Variables/RIFSPPFAAD90NB.csv to gs://stock_price_prediction_dataset/Data/data/FRED_Variables/RIFSPPFAAD90NB.csv
# Uploaded data/FRED_Variables/USRECDM.csv to gs://stock_price_prediction_dataset/Data/data/FRED_Variables/USRECDM.csv
# Uploaded data/FRED_Variables/DHHNGSP.csv to gs://stock_price_prediction_dataset/Data/data/FRED_Variables/DHHNGSP.csv
# Uploaded data/FRED_Variables/CBETHUSD.csv to gs://stock_price_prediction_dataset/Data/data/FRED_Variables/CBETHUSD.csv
# Uploaded data/FRED_Variables/NIKKEI225.csv to gs://stock_price_prediction_dataset/Data/data/FRED_Variables/NIKKEI225.csv
# Uploaded data/FRED_Variables/DCOILBRENTEU.csv to gs://stock_price_prediction_dataset/Data/data/FRED_Variables/DCOILBRENTEU.csv
# Uploaded data/FRED_Variables/DEXUSUK.csv to gs://stock_price_prediction_dataset/Data/data/FRED_Variables/DEXUSUK.csv
# Uploaded data/FRED_Variables/DAAA.csv to gs://stock_price_prediction_dataset/Data/data/FRED_Variables/DAAA.csv
# Uploaded data/FRED_Variables/AMERIBOR.csv to gs://stock_price_prediction_dataset/Data/data/FRED_Variables/AMERIBOR.csv
# Uploaded data/FRED_Variables/OBMMIJUMBO30YF.csv to gs://stock_price_prediction_dataset/Data/data/FRED_Variables/OBMMIJUMBO30YF.csv
# Uploaded data/FRED_Variables/DEXJPUS.csv to gs://stock_price_prediction_dataset/Data/data/FRED_Variables/DEXJPUS.csv
# Uploaded data/FRED_Variables/USRECD.csv to gs://stock_price_prediction_dataset/Data/data/FRED_Variables/USRECD.csv
# Uploaded data/FRED_Variables/DEXUSEU.csv to gs://stock_price_prediction_dataset/Data/data/FRED_Variables/DEXUSEU.csv
# Uploaded data/FRED_Variables/DCPF1M.csv to gs://stock_price_prediction_dataset/Data/data/FRED_Variables/DCPF1M.csv
# Uploaded data/FRED_Variables/DGS1.csv to gs://stock_price_prediction_dataset/Data/data/FRED_Variables/DGS1.csv
# Uploaded data/FRED_Variables/DCOILWTICO.csv to gs://stock_price_prediction_dataset/Data/data/FRED_Variables/DCOILWTICO.csv
# Uploaded pipeline/airflow/artifacts/pca_components.png to gs://stock_price_prediction_dataset/Data/pipeline/airflow/artifacts/pca_components.png
# Uploaded pipeline/airflow/artifacts/correlation_matrix_after_removing_correlated_features.png to gs://stock_price_prediction_dataset/Data/pipeline/airflow/artifacts/correlation_matrix_after_removing_correlated_features.png
# Uploaded pipeline/airflow/artifacts/yfinance_time_series.png to gs://stock_price_prediction_dataset/Data/pipeline/airflow/artifacts/yfinance_time_series.png
# Uploaded pipeline/airflow/dags/data/final_dataset.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/final_dataset.csv
# Uploaded pipeline/airflow/dags/data/ADS_index.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/ADS_index.csv
# Uploaded pipeline/airflow/dags/data/merged_original_dataset.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/merged_original_dataset.csv
# Uploaded pipeline/airflow/dags/data/fama_french.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/fama_french.csv
# Uploaded pipeline/airflow/dags/data/FRED_Variables/VIXCLS.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/FRED_Variables/VIXCLS.csv
# Uploaded pipeline/airflow/dags/data/FRED_Variables/DBAA.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/FRED_Variables/DBAA.csv
# Uploaded pipeline/airflow/dags/data/FRED_Variables/DCPN3M.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/FRED_Variables/DCPN3M.csv
# Uploaded pipeline/airflow/dags/data/FRED_Variables/CBBTCUSD.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/FRED_Variables/CBBTCUSD.csv
# Uploaded pipeline/airflow/dags/data/FRED_Variables/BAMLH0A0HYM2.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/FRED_Variables/BAMLH0A0HYM2.csv
# Uploaded pipeline/airflow/dags/data/FRED_Variables/BAMLH0A0HYM2EY.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/FRED_Variables/BAMLH0A0HYM2EY.csv
# Uploaded pipeline/airflow/dags/data/FRED_Variables/T10Y3M.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/FRED_Variables/T10Y3M.csv
# Uploaded pipeline/airflow/dags/data/FRED_Variables/DGS10.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/FRED_Variables/DGS10.csv
# Uploaded pipeline/airflow/dags/data/FRED_Variables/T10YIE.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/FRED_Variables/T10YIE.csv
# Uploaded pipeline/airflow/dags/data/FRED_Variables/T5YIE.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/FRED_Variables/T5YIE.csv
# Uploaded pipeline/airflow/dags/data/FRED_Variables/USRECDP.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/FRED_Variables/USRECDP.csv
# Uploaded pipeline/airflow/dags/data/FRED_Variables/RIFSPPFAAD90NB.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/FRED_Variables/RIFSPPFAAD90NB.csv
# Uploaded pipeline/airflow/dags/data/FRED_Variables/USRECDM.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/FRED_Variables/USRECDM.csv
# Uploaded pipeline/airflow/dags/data/FRED_Variables/DHHNGSP.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/FRED_Variables/DHHNGSP.csv
# Uploaded pipeline/airflow/dags/data/FRED_Variables/CBETHUSD.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/FRED_Variables/CBETHUSD.csv
# Uploaded pipeline/airflow/dags/data/FRED_Variables/NIKKEI225.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/FRED_Variables/NIKKEI225.csv
# Uploaded pipeline/airflow/dags/data/FRED_Variables/DCOILBRENTEU.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/FRED_Variables/DCOILBRENTEU.csv
# Uploaded pipeline/airflow/dags/data/FRED_Variables/DEXUSUK.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/FRED_Variables/DEXUSUK.csv
# Uploaded pipeline/airflow/dags/data/FRED_Variables/DAAA.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/FRED_Variables/DAAA.csv
# Uploaded pipeline/airflow/dags/data/FRED_Variables/AMERIBOR.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/FRED_Variables/AMERIBOR.csv
# Uploaded pipeline/airflow/dags/data/FRED_Variables/OBMMIJUMBO30YF.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/FRED_Variables/OBMMIJUMBO30YF.csv
# Uploaded pipeline/airflow/dags/data/FRED_Variables/DEXJPUS.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/FRED_Variables/DEXJPUS.csv
# Uploaded pipeline/airflow/dags/data/FRED_Variables/USRECD.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/FRED_Variables/USRECD.csv
# Uploaded pipeline/airflow/dags/data/FRED_Variables/DEXUSEU.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/FRED_Variables/DEXUSEU.csv
# Uploaded pipeline/airflow/dags/data/FRED_Variables/DCPF1M.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/FRED_Variables/DCPF1M.csv
# Uploaded pipeline/airflow/dags/data/FRED_Variables/DGS1.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/FRED_Variables/DGS1.csv
# Uploaded pipeline/airflow/dags/data/FRED_Variables/DCOILWTICO.csv to gs://stock_price_prediction_dataset/Data/pipeline/airflow/dags/data/FRED_Variables/DCOILWTICO.csv
# Uploaded assets/pca_components.png to gs://stock_price_prediction_dataset/Data/assets/pca_components.png
# Uploaded assets/correlation_matrix_after_removing_correlated_features.png to gs://stock_price_prediction_dataset/Data/assets/correlation_matrix_after_removing_correlated_features.png
# Uploaded assets/MLOps Group10 Diag.png to gs://stock_price_prediction_dataset/Data/assets/MLOps Group10 Diag.png
# Uploaded assets/yfinance_time_series.png to gs://stock_price_prediction_dataset/Data/assets/yfinance_time_series.png
# Uploaded assets/gcpbucket.png to gs://stock_price_prediction_dataset/Data/assets/gcpbucket.png
# Uploaded models/cleaned_data.csv to gs://stock_price_prediction_dataset/Data/models/cleaned_data.csv
# Selected CSV and PNG files uploaded to GCP bucket, excluding .gitignore entries.
